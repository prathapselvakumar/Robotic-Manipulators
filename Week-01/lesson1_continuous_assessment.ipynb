# %% [markdown]
# # About this Continuous Assessment
#
# This is a mock assessment is not worth any marks for this unit.
#
# |                 |                                                                                                                         |
# |-----------------|-------------------------------------------------------------------------------------------------------------------------|
# | Delivery method | Canvas submission of this file after completion.                                                                        |
# | Deadline        | As specified on Canvas.                                                                                                 |
# | ILOs            | Put to practice basic scalar, vector, and matrix algebra in Python, which will be used extensively throughout the unit. |
#
# #### Macros (do not touch these)
# $\providecommand{\myvec}[1]{{\mathbf{\boldsymbol{{#1}}}}}$
# $\providecommand{\mymatrix}[1]{{\mathbf{\boldsymbol{{#1}}}}}$

# %% [raw]
# \providecommand{\myvec}[1]{{\mathbf{\boldsymbol{{#1}}}}}
# \providecommand{\mymatrix}[1]{{\mathbf{\boldsymbol{{#1}}}}}

# %% [markdown]
# # Allowed packages
# Do not modify these. Do not add or remove packages.

# %%
# %pip install numpy --break-system-packages
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Allowed imports
# Do not modify these. Do not modify, add, or remove imports.

# %%
import numpy as np
from math import sin, cos, tan, sqrt

# %% [markdown]
# # Assigment description
#
# Each cell is tagged for the assessment, so do not delete or otherwise tamper with the cells. The assigment is to add content to each of the Python cells as requested.
#
# ## Verify the spreadsheet
#
# Your student ID will be used to assign you parameters. For each task, look into your row to see what you must implement.

# %% [markdown]
# ## Task A
# For $a,b,c\in\mathbb{R}$, use the $f_{A,1}$ in your spreadsheet to calculate
# $$r_A = cf_{A,1}(a,b).$$

# %%
# Do not modify these values. The original values in the file will be used for marking.
a = 1
b = 2
c = 3

# Add your answer below. Replace the `None`.
r_A = 1.5

# %% [markdown]
# ## Task B
#
# For $\mymatrix{A}$, $\mymatrix{B} \in \mathbb{R^{6\times6}}$, use the $f_{B,1}$, $f_{B,2}$, and $f_{B,3}$ in your spreadsheet to calculate
#
# $$ \myvec{r_B} = f_{B,3}(f_{B,1}{(\mymatrix{A})},f_{B,2}{(\mymatrix{B}})). $$

# %%
# Do not modify these values. The original values in the file will be used for marking.
A2 = np.array([[2, 1],
               [1, 2]])
B2 = np.array([[4, 3],
               [3, 4]])


# Add your answers below. Replace the `None`'s.
f_B_1 = A2.T
f_B_2 = -B2
r_B = f_B_1 + f_B_2
